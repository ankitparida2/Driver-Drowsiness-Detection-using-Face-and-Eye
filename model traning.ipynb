# %%
import tensorflow as tf
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout,Input,Flatten,Dense,MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Data Augumentation

# %%
batchsize=8

# %%
train_datagen= ImageDataGenerator(rescale=1./255, rotation_range=0.2,shear_range=0.2,
    zoom_range=0.2,width_shift_range=0.2,
    height_shift_range=0.2, validation_split=0.2)
train_data= train_datagen.flow_from_directory(r'C:\Users\ASUS\Downloads\deep learning\preaperd data\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical',subset='training')
validation_data= train_datagen.flow_from_directory(r'C:\Users\ASUS\Downloads\deep learning\preaperd data\train',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical', subset='validation')
# Out:
# Found 64675 images belonging to 2 classes.
# Found 16168 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_data = test_datagen.flow_from_directory(r'C:\Users\ASUS\Downloads\deep learning\preaperd data\test',
                                target_size=(80,80),batch_size=batchsize,class_mode='categorical')
# Out:
# Found 4059 images belonging to 2 classes.

# %%
bmodel = InceptionV3(include_top=False, weights='imagenet', input_tensor=Input(shape=(80,80,3)))
hmodel = bmodel.output
hmodel = Flatten()(hmodel)
hmodel = Dense(64, activation='relu')(hmodel)
hmodel = Dropout(0.5)(hmodel)
hmodel = Dense(2,activation= 'softmax')(hmodel)

model = Model(inputs=bmodel.input, outputs= hmodel)
for layer in bmodel.layers:
    layer.trainable = False

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 80, 80, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 39, 39,    │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 39, 39,    │         96 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping, ReduceLROnPlateau

# %%
checkpoint = ModelCheckpoint(r'C:\Users\ASUS\Downloads\deep learning\model folder\model.h5.keras',
                             monitor='val_loss', save_best_only=True, verbose=3)

earlystop = EarlyStopping(monitor = 'val_loss', patience=7, verbose= 3, restore_best_weights=True)

learning_rate = ReduceLROnPlateau(monitor= 'val_loss', patience=3, verbose= 3, )

callbacks=[checkpoint,earlystop,learning_rate]

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(
    train_data,
    steps_per_epoch=train_data.samples //batchsize,
    validation_data=validation_data,
    validation_steps=validation_data.samples // batchsize,
    callbacks=callbacks, 
    epochs=8
)
# Out:
# Epoch 1/8
#    1/8084 ━━━━━━━━━━━━━━━━━━━━ 20:11:28 9s/step - accuracy: 0.5000 - loss: 1.0002
# C:\Users\ASUS\OneDrive\Documents\jupyter\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 8083/8084 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9086 - loss: 0.2319
# Epoch 1: val_loss improved from inf to 0.21071, saving model to C:\Users\ASUS\Downloads\deep learning\model folder\model.h5.keras
# 8084/8084 ━━━━━━━━━━━━━━━━━━━━ 496s 60ms/step - accuracy: 0.9086 - loss: 0.2319 - val_accuracy: 0.9151 - val_loss: 0.2107 - learning_rate: 0.0010
# Epoch 2/8
#    1/8084 ━━━━━━━━━━━━━━━━━━━━ 4:52 36ms/step - accuracy: 0.7500 - loss: 0.5356
# ...

# %%
acc_tr, loss_tr = model.evaluate(train_data)
print(acc_tr)
print(loss_tr)
# Out:
# 8085/8085 ━━━━━━━━━━━━━━━━━━━━ 359s 44ms/step - accuracy: 0.9353 - loss: 0.1589
# 0.15797138214111328
# 0.9363741874694824

# %%
acc_vr, loss_vr = model.evaluate(validation_data)
print(acc_vr)
print(loss_vr)
# Out:
# 2021/2021 ━━━━━━━━━━━━━━━━━━━━ 88s 44ms/step - accuracy: 0.9161 - loss: 0.2084
# 0.21118637919425964
# 0.9154502749443054

# %%
acc_test, loss_test = model.evaluate(test_data)
print(acc_tr)
print(loss_tr)
# Out:
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 39s 76ms/step - accuracy: 0.8605 - loss: 0.2904
# 0.15797138214111328
# 0.9363741874694824

# %%
from sklearn.metrics import classification_report
import numpy as np

# Ensure predictions match the full test set
predictions = model.predict(test_data, steps=test_data.samples // test_data.batch_size + 1)
predicted_classes = np.argmax(predictions, axis=1)

# Extract the true labels
true_classes = test_data.classes

# Get class labels from the generator
class_labels = list(test_data.class_indices.keys())

# Generate and display the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print("Classification Report:\n", report)
# Out:
# 508/508 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#  closed eyes       0.57      0.70      0.63      2325
#    open eyes       0.43      0.31      0.36      1734
#
#     accuracy                           0.53      4059
#    macro avg       0.50      0.50      0.49      4059
# weighted avg       0.51      0.53      0.51      4059
